# %%
import datetime
import pandas as pd
import io
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_column',None)
tomorrow = (datetime.date.today() + datetime.timedelta(days=1)).isoformat() #get tomorrow in iso format as needed'''
url = pd.read_html("https://markets.ft.com/data/funds/tearsheet/historical?s=LU0119216553:EUR", header=0)
table = url[0]
gsef_latest = table[['Date', 'Close']]
gsef_latest_selected= gsef_latest.copy()
# Out:
#                                              Date   Close
# 0     Tuesday, February 08, 2022Tue, Feb 08, 2022  582.84
# 1      Monday, February 07, 2022Mon, Feb 07, 2022  579.94
# 2      Friday, February 04, 2022Fri, Feb 04, 2022  581.25
# 3    Thursday, February 03, 2022Thu, Feb 03, 2022  582.48
# 4   Wednesday, February 02, 2022Wed, Feb 02, 2022  602.13
# 5     Tuesday, February 01, 2022Tue, Feb 01, 2022  596.55
# 6       Monday, January 31, 2022Mon, Jan 31, 2022  593.49
# 7       Friday, January 28, 2022Fri, Jan 28, 2022  581.57
# 8     Thursday, January 27, 2022Thu, Jan 27, 2022  572.75
# 9    Wednesday, January 26, 2022Wed, Jan 26, 2022  568.94
# 10     Tuesday, January 25, 2022Tue, Jan 25, 2022  566.85
# 11      Monday, January 24, 2022Mon, Jan 24, 2022  576.14
# 12      Friday, January 21, 2022Fri, Jan 21, 2022  580.19
# 13    Thursday, January 20, 2022Thu, Jan 20, 2022  593.54
# 14   Wednesday, January 19, 2022Wed, Jan 19, 2022  594.05
# 15     Tuesday, January 18, 2022Tue, Jan 18, 2022  595.20
# 16      Friday, January 14, 2022Fri, Jan 14, 2022  602.76
# 17    Thursday, January 13, 2022Thu, Jan 13, 2022  607.08
# 18   Wednesday, January 12, 2022Wed, Jan 12, 2022  619.67
# 19     Tuesday, January 11, 2022Tue, Jan 11, 2022  617.32
# 20      Monday, January 10, 2022Mon, Jan 10, 2022  612.41

# %%
gsef_latest_selected['Date'] = gsef_latest_selected.loc[:,'Date'].str[-12:]
gsef_latest_selected['Date'] = pd.to_datetime(gsef_latest_selected['Date'])

gsef_latest_selected
# Out:
#          Date   Close
# 0  2022-02-08  582.84
# 1  2022-02-07  579.94
# 2  2022-02-04  581.25
# 3  2022-02-03  582.48
# 4  2022-02-02  602.13
# 5  2022-02-01  596.55
# 6  2022-01-31  593.49
# 7  2022-01-28  581.57
# 8  2022-01-27  572.75
# 9  2022-01-26  568.94
# 10 2022-01-25  566.85
# 11 2022-01-24  576.14
# 12 2022-01-21  580.19
# 13 2022-01-20  593.54
# 14 2022-01-19  594.05
# 15 2022-01-18  595.20
# 16 2022-01-14  602.76
# 17 2022-01-13  607.08
# 18 2022-01-12  619.67
# 19 2022-01-11  617.32
# 20 2022-01-10  612.41

# %%
gsef_latest_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    21 non-null     datetime64[ns]
#  1   Close   21 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 464.0 bytes

# %%
gsef_historical= pd.read_csv('gsef_folder/historical_gsef.csv', parse_dates=['Date'])

gsef_historical = gsef_historical

# %%
gsef_historical
# Out:
#            Date   Close
# 0    2004-12-31  139.21
# 1    2004-12-30  138.86
# 2    2004-12-29  138.76
# 3    2004-12-28  138.91
# 4    2004-12-27  138.45
# ...         ...     ...
# 4541 2022-01-07  618.64
# 4542 2022-01-06  626.87
# 4543 2022-01-05  631.73
# 4544 2022-01-04  646.89
# 4545 2022-01-03  651.95
#
# [4546 rows x 2 columns]

# %%
gsef_historical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4546 entries, 257 to 4541
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4546 non-null   datetime64[ns]
#  1   Close   4546 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 106.5 KB

# %%
gsef = pd.concat([gsef_latest_selected, gsef_historical], ignore_index=True).sort_values(by="Date")

gsef = gsef.reset_index(drop=True)

# %%
gsef = gsef.drop_duplicates()

# %%
gsef.to_csv('gsef_folder/historical_gsef.csv', index=False)

# %%
gsef.pivot(index='Date', columns='Close', values='Close').plot(marker='o', legend=False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gsef.plot(x= 'Date', figsize=(10,10), title= 'GSEF Price by Date', legend=False)

plt.show()
